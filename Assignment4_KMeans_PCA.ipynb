# %%
from sklearn.decomposition import PCAfrom sklearn.cluster import KMeansdata=[[1,2,3],[2,3,4],[3,4,5],[10,10,10]]pca=PCA(n_components=2)reduced=pca.fit_transform(data)kmeans=KMeans(n_clusters=2)labels=kmeans.fit_predict(reduced)print(labels)
