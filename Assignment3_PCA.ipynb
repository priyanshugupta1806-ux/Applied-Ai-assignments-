# %%
from sklearn.decomposition import PCAimport matplotlib.pyplot as pltdata=[[1,2,3],[2,3,4],[3,4,5],[10,10,10]]pca=PCA(n_components=2)reduced=pca.fit_transform(data)plt.scatter(reduced[:,0],reduced[:,1])plt.show()
