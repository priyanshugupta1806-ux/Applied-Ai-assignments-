# %% [markdown]
# # KMeans Clustering
#
# **Objective:** Cluster data into groups

# %%
from sklearn.cluster import KMeansimport matplotlib.pyplot as pltdata=[[1,2],[2,3],[3,4],[10,10],[11,11]]kmeans=KMeans(n_clusters=2)labels=kmeans.fit_predict(data)plt.scatter([x[0] for x in data],[x[1] for x in data],c=labels)plt.show()

# %% [markdown]
# ## Conclusion
# This model was successfully implemented and tested.
