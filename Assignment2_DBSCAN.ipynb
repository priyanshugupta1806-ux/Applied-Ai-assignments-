# %%
from sklearn.cluster import DBSCANimport matplotlib.pyplot as pltdata=[[1,2],[2,3],[3,4],[10,10],[11,11]]db=DBSCAN(eps=2,min_samples=2)labels=db.fit_predict(data)plt.scatter([x[0] for x in data],[x[1] for x in data],c=labels)plt.show()
