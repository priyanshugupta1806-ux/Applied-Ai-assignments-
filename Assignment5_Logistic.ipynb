# %%
from sklearn.linear_model import LogisticRegressionX=[[1,2],[2,3],[3,4],[10,10]]y=[0,0,0,1]model=LogisticRegression()model.fit(X,y)print(model.predict(X))
